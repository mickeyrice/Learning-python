# %% [markdown]
# # Practice importing and manipulating datasets

# %% [markdown]
# # Checking the Current Working Directory
#
# This notebook demonstrates how to check the current working directory using the `os` module in Python.
#
# - The first cell imports the `os` module.
# - The second cell retrieves and prints the current working directory.

# %%
import os

# %%
# Get and print the current working directory
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)
# Out:
# Current Working Directory: /Users/mickey.rice

# %% [markdown]
# # Changing the Current Working Directory
#
# This notebook demonstrates how to change the current working directory using the `os` module in Python.
#
# - The first cell imports the `os` module.
# - The second cell changes the current working directory and verifies the change.

# %%
# Change the Current Working Directory
# Specify the new directory path
new_directory = '/Users/mickey.rice/Desktop/Dissertation/PMD'

# Change the current working directory
os.chdir(new_directory)

# Verify the change
current_directory = os.getcwd()
print("Current Working Directory:", current_directory)

# %% [markdown]
# # Importing Data into Python
#
# This notebook demonstrates how to import data from CSV and Excel files using the `pandas` library.
#
# - The first cell imports the necessary libraries.
# - The second cell loads data from a CSV file.
# - The third cell loads data from an Excel file.

# %%
# Cell 1: Import Libraries
import pandas as pd

# %%
# Cell 2: Load the CSV File
csv_file_path = 'PMD.csv'
df_csv = pd.read_csv(csv_file_path)
print("CSV Data:")
display(df_csvd.head())
# Out:
# CSV Data:
#       ID   Accuracy           RT  PHQ9  CESD  DASS  PRMQ1  Confidence  JOL  \
# 0  PMD02  73.611111  1116.633001    16    33     7     27          11   60
# 1  PMD03  76.388889   805.957503    13    26     0     28           8   83
# 2  PMD04  77.777778   713.443193    13    37    14     27           8   95
# 3  PMD05  68.055556  1137.573536    16    40    16     37          22   87
# 4  PMD06  18.055556   796.787629    10    32    10     27          12   70
#
#        N300        PP   Age     Sex                 Gender        Race  \
# 0 -7.268333  2.764000   NaN  Female                 Female  \te. White
# 1 -9.697000  0.866000  18.0  Female                 Female    e. White
# 2 -1.530000 -4.111333   NaN    Male  Transgender Nonbinary  \te. White
# 3 -2.507000  0.486333  18.0  Female                 Female  \te. White
# 4 -2.468333  2.281333  18.0  Female                 Female    e. White
#
#                      Ethnicity    Handedness
# ...

# %%
# Cell 3: Load the Excel File
excel_file_path = 'PMD.xlsx'
df_excel = pd.read_excel(excel_file_path)
print("Excel Data:")
display(df_excel.head())
# Out:
# Excel Data:
#       ID   Accuracy           RT  PHQ9  CESD  DASS  PRMQ1  Confidence  JOL  \
# 0  PMD02  73.611111  1116.633001    16    33     7     27          11   60
# 1  PMD03  76.388889   805.957503    13    26     0     28           8   83
# 2  PMD04  77.777778   713.443193    13    37    14     27           8   95
# 3  PMD05  68.055556  1137.573536    16    40    16     37          22   87
# 4  PMD06  18.055556   796.787629    10    32    10     27          12   70
#
#        N300        PP   Age     Sex                 Gender        Race  \
# 0 -7.268333  2.764000   NaN  Female                 Female  \te. White
# 1 -9.697000  0.866000  18.0  Female                 Female    e. White
# 2 -1.530000 -4.111333   NaN    Male  Transgender Nonbinary  \te. White
# 3 -2.507000  0.486333  18.0  Female                 Female  \te. White
# 4 -2.468333  2.281333  18.0  Female                 Female    e. White
#
#                      Ethnicity    Handedness
# ...
